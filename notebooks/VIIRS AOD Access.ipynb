# %%
import matplotlib.pyplot as plt
import h5py
import numpy as np

# %%
f = 'IVAOT_npp_d20150901_t0632421_e0634063_b19917_c20150901082907489523_noaa_ops.h5'

# %%
ds = h5py.File(f,  "r")

# %%
ds['All_Data'].keys()
# Out:
# [u'VIIRS-Aeros-Opt-Thick-IP_All']

# %%
ds['All_Data']['VIIRS-Aeros-Opt-Thick-IP_All'].keys()
# Out:
# [u'QF1', u'QF2', u'QF3', u'QF4', u'QF5', u'angexp', u'aotSlant550', u'faot550']

# %%
aot = ds['All_Data']['VIIRS-Aeros-Opt-Thick-IP_All']['faot550'][:]

# %%
aot[aot < 0] = 0
plt.figure(figsize=(15,15))
plt.imshow(aot)
plt.show()

# %%
ds['Data_Products'].keys()
# Out:
# [u'VIIRS-Aeros-Opt-Thick-IP']

# %%
ds['Data_Products']['VIIRS-Aeros-Opt-Thick-IP'].keys()
# Out:
# [u'VIIRS-Aeros-Opt-Thick-IP_Aggr', u'VIIRS-Aeros-Opt-Thick-IP_Gran_0']

# %%
ds['Data_Products']['VIIRS-Aeros-Opt-Thick-IP']['VIIRS-Aeros-Opt-Thick-IP_Gran_0'][:]
# Out:
# array([<HDF5 region reference>, <HDF5 region reference>,
#        <HDF5 region reference>, <HDF5 region reference>,
#        <HDF5 region reference>, <HDF5 region reference>,
#        <HDF5 region reference>, <HDF5 region reference>], dtype=object)
